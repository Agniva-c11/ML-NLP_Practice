# %%
# !pip install nltk

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/agniva/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/agniva/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/agniva/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /home/agniva/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/agniva/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# ...

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
corpus = "Separated from his daughter, a father with an intellectual disability must prove his innocence when he is jailed for the death of a commander's child." \
"Hello my name is Agniva Chakravarty"

# %%
print(word_tokenize(corpus))
print(sent_tokenize(corpus))
# Out:
# ['Separated', 'from', 'his', 'daughter', ',', 'a', 'father', 'with', 'an', 'intellectual', 'disability', 'must', 'prove', 'his', 'innocence', 'when', 'he', 'is', 'jailed', 'for', 'the', 'death', 'of', 'a', 'commander', "'s", 'child.Hello', 'my', 'name', 'is', 'Agniva', 'Chakravarty']
# ["Separated from his daughter, a father with an intellectual disability must prove his innocence when he is jailed for the death of a commander's child.Hello my name is Agniva Chakravarty"]

# %%
corpus1 = """
Hello and welcome.
My name is Agniva Chakravarty.
I am an ML Engineer.
"""

# %%
documents = sent_tokenize(corpus1)
documents
# Out:
# ['\nHello and welcome.',
#  'My name is Agniva Chakravarty.',
#  'I am an ML Engineer.']

# %%
for sentences in documents:
    print(word_tokenize(sentences))
# Out:
# ['Hello', 'and', 'welcome', '.']
# ['My', 'name', 'is', 'Agniva', 'Chakravarty', '.']
# ['I', 'am', 'an', 'ML', 'Engineer', '.']

# %%
words2 = ["eating", "writable", "runner", "fighter", "going", "finalised", "history", "programming"]

# Porter Stemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
for word in words2:
    print(word + "----->" + stemmer.stem(word))
# Out:
# eating----->eat
# writable----->writabl
# runner----->runner
# fighter----->fighter
# going----->go
# finalised----->finalis
# history----->histori
# programming----->program

# %%
# Snowball Stemmer
from nltk.stem import SnowballStemmer
snow_stemmer = SnowballStemmer('english')
for word in words2:
    print(word + "----->" + snow_stemmer.stem(word))
# Out:
# eating----->eat
# writable----->writabl
# runner----->runner
# fighter----->fighter
# going----->go
# finalised----->finalis
# history----->histori
# programming----->program

# %%
# Regexp Stemmer
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min = 4)
for word in words2:
    print(word + "----->" + reg_stemmer.stem(word))
# Out:
# eating----->eat
# writable----->writ
# runner----->runner
# fighter----->fighter
# going----->go
# finalised----->finalised
# history----->history
# programming----->programm

# %%
# Lemmatization
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
for word in words2:
    print(word + "----->" + lemmatizer.lemmatize(word, pos = 'v'))
# Out:
# eating----->eat
# writable----->writable
# runner----->runner
# fighter----->fighter
# going----->go
# finalised----->finalise
# history----->history
# programming----->program

# %%
# Stopwords
corpus3 = """
    Myself Agniva Chakravarty, a recent graduate from College of Engineering and Management, Kolaghat.
    I completed my B.tech in the field of Electronics and Communication Engineering with a CGPA of 8.15.
    I have also completed an internship at a startup. I developed a data enrichment system that automated B2B contact extraction from app metadata.
"""

from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
# Remove stop words using stemming and tokenisation
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

sentences = sent_tokenize(corpus3)
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ''.join(words)

# %%
sentences
# Out:
# ['myselfagnivachakravarti,recentgraduatcollegenginmanag,kolaghat.',
#  'icompletb.techfieldelectroncommunengincgpa8.15.',
#  'ialsocompletinternshipstartup.',
#  'idevelopdataenrichsystemautomb2bcontactextractappmetadata.']

# %%
# Removing stop words using lemmatization and tokenization
corpus4 = """
    Myself Agniva Chakravarty, a recent graduate from College of Engineering and Management, Kolaghat.
    I completed my B.tech in the field of Electronics and Communication Engineering with a CGPA of 8.15.
    I have also completed an internship at a startup. I developed a data enrichment system that automated B2B contact extraction from app metadata.
"""
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

sentences = sent_tokenize(corpus4)
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [lemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ''.join(words)

# %%
sentences
# Out:
# ['MyselfAgnivaChakravarty,recentgraduateCollegeEngineeringManagement,Kolaghat.',
#  'IcompletedB.techfieldElectronicsCommunicationEngineeringCGPA8.15.',
#  'Ialsocompletedinternshipstartup.',
#  'IdevelopeddataenrichmentsystemautomatedB2Bcontactextractionappmetadata.']
